# %%
import pandas as pd
data = pd.read_csv('/content/Housing.csv')

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data['airconditioning'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
data[['stories','bathrooms','bedrooms']].corr()
# Out:
#             stories  bathrooms  bedrooms
# stories    1.000000   0.326165  0.408564
# bathrooms  0.326165   1.000000  0.373930
# bedrooms   0.408564   0.373930  1.000000

# %%
data['bedrooms'].mean()
# Out:
# np.float64(2.9651376146788992)

# %%
data[data['basement']=='yes']['area'].mean()
# Out:
# np.float64(5290.502617801048)

# %%
data[data['basement']=='no']['area'].mean()
# Out:
# np.float64(5075.025423728814)

# %%
plt.scatter(x=data['bathrooms'],y=data['bedrooms'])
plt.title("Bathrooms vs Bedrooms")
plt.show()

# %%
plt.scatter(x=data['area'],y=data['price'])
plt.title("Area vs Price")
plt.show()

# %%
data['area'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['price'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data.furnishingstatus = le.fit_transform(data.furnishingstatus)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data.mainroad = le.fit_transform(data.furnishingstatus)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data.guestroom = le.fit_transform(data.furnishingstatus)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data.basement = le.fit_transform(data.furnishingstatus)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data.hotwaterheating = le.fit_transform(data.furnishingstatus)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data.airconditioning = le.fit_transform(data.furnishingstatus)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data.prefarea = le.fit_transform(data.furnishingstatus)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  basement  \
# 0  13300000  7420         4          2        3         0         0
# 1  12250000  8960         4          4        4         0         0
# 2  12250000  9960         3          2        2         1         1
# 3  12215000  7500         4          2        2         0         0
# 4  11410000  7420         4          1        2         0         0
#
#    hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 0                0                0        2         0                 0
# 1                0                0        3         0                 0
# 2                1                1        2         1                 1
# 3                0                0        3         0                 0
# 4                0                0        2         0                 0

# %%
data= data.drop('prefarea',axis = 1)

# %%
n.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  basement  hotwaterheating  \
# 0  7420         4          2        3         0         0                0
# 1  8960         4          4        4         0         0                0
# 2  9960         3          2        2         1         1                1
# 3  7500         4          2        2         0         0                0
# 4  7420         4          1        2         0         0                0
#
#    airconditioning  parking  prefarea  furnishingstatus
# 0                0        2         0                 0
# 1                0        3         0                 0
# 2                1        2         1                 1
# 3                0        3         0                 0
# 4                0        2         0                 0

# %%
data.furnishingstatus.unique()
# Out:
# array([0, 1, 2])

# %%
le.classes_
# Out:
# array([0, 1, 2])

# %%
x = data.drop('price',axis = 1)

# %%
x.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  basement  airconditioning  \
# 0  7420         4          2        3         0         0                0
# 1  8960         4          4        4         0         0                0
# 2  9960         3          2        2         1         1                1
# 3  7500         4          2        2         0         0                0
# 4  7420         4          1        2         0         0                0
#
#    parking  furnishingstatus
# 0        2                 0
# 1        3                 0
# 2        2                 1
# 3        3                 0
# 4        2                 0

# %%
y = data.price

# %%
y.head()
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2,random_state=3)

# %%
x_train.shape,x_test.shape, y_train.shape,y_test.shape
# Out:
# ((436, 9), (109, 9), (436,), (109,))

# %%
x_train.head()
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  basement  airconditioning  \
# 425  3185         2          1        1         0         0                0
# 243  2550         3          1        2         0         0                0
# 440  3640         4          1        2         2         2                2
# 279  6360         2          1        1         0         0                0
# 395  3600         6          1        2         2         2                2
#
#      parking  furnishingstatus
# 425        2                 0
# 243        0                 0
# 440        0                 2
# 279        0                 0
# 395        1                 2

# %%
x_train.head()
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  basement  airconditioning  \
# 425  3185         2          1        1         0         0                0
# 243  2550         3          1        2         0         0                0
# 440  3640         4          1        2         2         2                2
# 279  6360         2          1        1         0         0                0
# 395  3600         6          1        2         2         2                2
#
#      parking  furnishingstatus
# 425        2                 0
# 243        0                 0
# 440        0                 2
# 279        0                 0
# 395        1                 2

# %%
y.head()
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2,random_state=3)

# %%
x_train.shape,x_test.shape, y_train.shape,y_test.shape
# Out:
# ((436, 9), (109, 9), (436,), (109,))

# %%
x_train.head()
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  basement  airconditioning  \
# 425  3185         2          1        1         0         0                0
# 243  2550         3          1        2         0         0                0
# 440  3640         4          1        2         2         2                2
# 279  6360         2          1        1         0         0                0
# 395  3600         6          1        2         2         2                2
#
#      parking  furnishingstatus
# 425        2                 0
# 243        0                 0
# 440        0                 2
# 279        0                 0
# 395        1                 2

# %%
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)
print("R2  :", r2)
# Out:
# MAE : 896433.2978233569
# MSE : 1327514735890.1372
# RMSE: 1152178.256994176
# R2  : 0.5183565226488396

# %%
n.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  basement  \
# 0  13300000  7420         4          2        3         0         0
# 1  12250000  8960         4          4        4         0         0
# 2  12250000  9960         3          2        2         1         1
# 3  12215000  7500         4          2        2         0         0
# 4  11410000  7420         4          1        2         0         0
#
#    hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 0                0                0        2         0                 0
# 1                0                0        3         0                 0
# 2                1                1        2         1                 1
# 3                0                0        3         0                 0
# 4                0                0        2         0                 0

# %%
n.drop('price',axis=1,inplace =True)
# Out:
# /tmp/ipython-input-3459821926.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   n.drop('price',axis=1,inplace =True)

# %%
model.predict(n)
# Out:
# array([12068668.87734412, 11858174.32193843, 11024404.66455247,
#        10452509.72564644,  8995091.39290296])

# %%
import joblib
joblib.dump(model,'model.pk2.5')
# Out:
# ['model.pk2.5']
